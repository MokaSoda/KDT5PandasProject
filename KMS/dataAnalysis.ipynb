# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mp
import seaborn as sns
import re
import random

def randomColor():
    from random import choice
    color = "#" + "".join([choice("0123456789ABCDEF") for j in range(6)])
    return color

# %%
# sns.set_theme(style="darkgrid")
sns.set_style('darkgrid', {'legend.frameon':True})
# 나눔 고딕으로 설정
font_path = "C:/Windows/Fonts/NanumGothic.ttf"
font_name = font_path.split("/")[-1]
font_name = font_name.split(".")[0]
plt.rc('font', family=font_name)
plt.rcParams["figure.autolayout"] = True

# %%
file = '../.venv/tickets.csv'

# %%
df_test = pd.read_csv(file)

# %%
alpha = [
 'tran_date',
 'play_date',
 'pre_open_date',
 'open_date',
]
df_test[alpha] = df_test[alpha].apply(lambda x: pd.to_datetime(x, errors='coerce', format="%Y%m%d"))
playdate = df_test[df_test['ticket_cancel'] == 0]['play_date']

# %%
target = sns.histplot(playdate, bins=60, color='green')
target.set_title('공연예매추이', fontdict={'fontsize': 20, 'fontweight': 'bold'}, pad = 15)
target.set_ylabel(
    "판매횟수", 
    # loc = 'top', 
    rotation = 0,
    y = 1.05,
    x = 0
    )
target.set_xlabel("")
target.figure.savefig('공연관람객수추이.png', dpi=600)
plt.show()

# %%
withprice = pd.concat([playdate, df_test[df_test['ticket_cancel'] == 0]['price']], axis=1)
cutter = pd.cut(withprice['play_date'], bins = 60)
cutter.name = 'cutter'
withprice = pd.concat([withprice, cutter], axis=1)
print(withprice)
cutterlist = cutter.unique().tolist()
cutterlist.sort()

yearprice = pd.Series()
for x in cutterlist:
    yearprice[x] = withprice[withprice['cutter'] == x]['price'].sum()

target = sns.barplot(x=yearprice.index, y=yearprice.values)
target.set_xlabel("", fontsize=15)
# target.set_xticklabels(['2019', '2020', '2021', '2022', '2023/07/07'])
# target.set_xticks([0, 1, 2, 3, 4])
target.set(yticklabels=[], xticklabels=[])
target.set_title("공연 매출 추이", fontdict={'fontsize': 20, 'fontweight': 'bold'}, pad = 15)
target.figure.savefig('공연매출추이.png', dpi=600)
# Out:
#          play_date   price                                      cutter
# 1       2021-10-09       0  (2021-09-26 00:24:00, 2021-10-24 05:36:00]
# 2       2022-11-05       0  (2022-10-26 01:12:00, 2022-11-23 06:24:00]
# 3       2019-07-31       0  (2019-07-28 22:48:00, 2019-08-26 04:00:00]
# 4       2022-03-02  180000  (2022-02-14 02:24:00, 2022-03-14 07:36:00]
# 6       2019-11-09       0  (2019-10-21 14:24:00, 2019-11-18 19:36:00]
# ...            ...     ...                                         ...
# 1920863 2019-07-06       0  (2019-06-30 17:36:00, 2019-07-28 22:48:00]
# 1920864 2023-04-08   21000  (2023-03-16 03:12:00, 2023-04-13 08:24:00]
# 1920865 2021-06-19   24000  (2021-06-05 03:36:00, 2021-07-03 08:48:00]
# 1920866 2021-11-27       0  (2021-11-21 10:48:00, 2021-12-19 16:00:00]
# 1920867 2021-06-19       0  (2021-06-05 03:36:00, 2021-07-03 08:48:00]
#
# [1602195 rows x 3 columns]

# %%
# 데이터 로딩
# 데이터에서 불필요한 요소를 drop 하고 미리 날자 관련 데이터는 미리 파싱되도록 처리

df = pd.read_csv(file, parse_dates=['tran_date','play_date', 'pre_open_date', 'open_date'], )
df.tail()
df = df[df['place'] == '콘서트홀']
df.drop(columns=['membership_type_6', 'place'], inplace=True)

# %%
# 타임만 있는 데이터의 경우 수동으로 파싱되도록 처리함
df['play_st_time'] = pd.to_timedelta(df['play_st_time'])
# change tran_time to datetime dtype as %H%M
df['tran_time'] =  pd.to_timedelta(df['tran_time'])

# 카테고리화가 가능한 데이터는 한번에 카테고리화 함
categorized = ['performance_code', 'genre', 'seat', 'ticket_cancel', 'discount_type','gender']
df[categorized] = df[categorized].astype('category')

# %%
df[['member_yn']] = df[['member_yn']].replace({'Y':True, 'N':False})
df_mem_type = [ 
'membership_type_1',
 'membership_type_2',
 'membership_type_3',
 'membership_type_4',
 'membership_type_5']
df[df_mem_type] = df[df_mem_type].astype('category') 


df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1096968 entries, 0 to 1920864
# Data columns (total 22 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   age                484517 non-null   float64
#  1   gender             484867 non-null   category
#  2   membership_type_1  484867 non-null   category
#  3   membership_type_2  389737 non-null   category
#  4   membership_type_3  140468 non-null   category
#  5   membership_type_4  25160 non-null    category
#  6   membership_type_5  1110 non-null     category
#  7   tran_date          1096968 non-null  datetime64[ns]
#  8   tran_time          1096968 non-null  timedelta64[ns]
#  9   play_date          1096968 non-null  datetime64[ns]
#  10  play_st_time       1096968 non-null  timedelta64[ns]
#  11  seat               1096968 non-null  category
#  12  price              1096968 non-null  int64
#  13  ticket_cancel      1096968 non-null  category
#  14  discount_type      1096968 non-null  category
#  15  performance_code   1096968 non-null  category
#  16  pre_open_date      701323 non-null   datetime64[ns]
#  17  open_date          1096968 non-null  datetime64[ns]
#  18  genre              1071895 non-null  category
#  19  running_time       1096968 non-null  int64
#  20  intermission       1096968 non-null  int64
#  21  member_yn          1096968 non-null  bool
# dtypes: bool(1), category(11), datetime64[ns](4), float64(1), int64(3), timedelta64[ns](2)
# memory usage: 107.9 MB

# %%
columns = ['age',
 'gender',
 'membership_type_1',
 'membership_type_2',
 'membership_type_3',
 'membership_type_4',
 'membership_type_5',
 'membership_type_6',
 'tran_date',
 'tran_time',
 'play_date',
 'play_st_time',
 'seat',
 'price',
 'ticket_cancel',
 'discount_type',
 'performance_code',
 'pre_open_date',
 'open_date',
 'genre',
 'place',
 'running_time',
 'intermission',
 'member_yn']

hangul = [
'나이',
'성별',
'멤버십종류1',
'멤버십종류2',
'멤버십종류3',
'멤버십종류4',
'멤버십종류5',
'멤버십종류6',
'예매 거래일자',
'예매 거래시간',
'공연날짜',
'공연시작시간',
'좌석번호',
'최종예매가격',
'예매취소여부',
'할인내역',
'공연명 코드',
'선예매시작일',
'예매시작일',
'장르',
'러닝타임',
'휴게시간',
'회원여부'
]
df.rename(dict(zip(columns, hangul)), axis='columns', inplace=True)

# %%
df[df['회원여부']& df['최종예매가격'].gt(0)]['최종예매가격'].plot(kind='hist', bins=50)
plt.xlabel("가격")
plt.show()

# %%
df[~df['회원여부'] & df['최종예매가격'].gt(0) ]['최종예매가격'].plot(kind='hist', bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1096968 entries, 0 to 1920864
# Data columns (total 22 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   나이         484517 non-null   float64
#  1   성별         484867 non-null   category
#  2   멤버십종류1     484867 non-null   category
#  3   멤버십종류2     389737 non-null   category
#  4   멤버십종류3     140468 non-null   category
#  5   멤버십종류4     25160 non-null    category
#  6   멤버십종류5     1110 non-null     category
#  7   예매 거래일자    1096968 non-null  datetime64[ns]
#  8   예매 거래시간    1096968 non-null  timedelta64[ns]
#  9   공연날짜       1096968 non-null  datetime64[ns]
#  10  공연시작시간     1096968 non-null  timedelta64[ns]
#  11  좌석번호       1096968 non-null  category
#  12  최종예매가격     1096968 non-null  int64
#  13  예매취소여부     1096968 non-null  category
#  14  할인내역       1096968 non-null  category
#  15  공연명 코드     1096968 non-null  category
#  16  선예매시작일     701323 non-null   datetime64[ns]
#  17  예매시작일      1096968 non-null  datetime64[ns]
#  18  장르         1071895 non-null  category
#  19  휴게시간       1096968 non-null  int64
#  20  회원여부       1096968 non-null  int64
#  21  member_yn  1096968 non-null  bool
# dtypes: bool(1), category(11), datetime64[ns](4), float64(1), int64(3), timedelta64[ns](2)
# memory usage: 107.9 MB

# %%
df = df[df['공연날짜'] > '2022-07-07']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 422528 entries, 15 to 1920864
# Data columns (total 22 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   나이         210516 non-null  float64
#  1   성별         210610 non-null  category
#  2   멤버십종류1     210610 non-null  category
#  3   멤버십종류2     169838 non-null  category
#  4   멤버십종류3     60842 non-null   category
#  5   멤버십종류4     10839 non-null   category
#  6   멤버십종류5     471 non-null     category
#  7   예매 거래일자    422528 non-null  datetime64[ns]
#  8   예매 거래시간    422528 non-null  timedelta64[ns]
#  9   공연날짜       422528 non-null  datetime64[ns]
#  10  공연시작시간     422528 non-null  timedelta64[ns]
#  11  좌석번호       422528 non-null  category
#  12  최종예매가격     422528 non-null  int64
#  13  예매취소여부     422528 non-null  category
#  14  할인내역       422528 non-null  category
#  15  공연명 코드     422528 non-null  category
#  16  선예매시작일     273321 non-null  datetime64[ns]
#  17  예매시작일      422528 non-null  datetime64[ns]
#  18  장르         405803 non-null  category
#  19  휴게시간       422528 non-null  int64
#  20  회원여부       422528 non-null  int64
#  21  member_yn  422528 non-null  bool
# dtypes: bool(1), category(11), datetime64[ns](4), float64(1), int64(3), timedelta64[ns](2)
# memory usage: 41.6 MB

# %%
df[~df['회원여부'] & df['최종예매가격'].gt(0)]
df
# Out:
#            나이   성별 멤버십종류1 멤버십종류2 멤버십종류3 멤버십종류4 멤버십종류5    예매 거래일자  \
# 15       50.0    M     골드     무료    NaN    NaN    NaN 2022-10-30
# 16       30.0    F     무료     그린    NaN    NaN    NaN 2023-02-24
# 20        NaN  NaN    NaN    NaN    NaN    NaN    NaN 2022-11-12
# 28       20.0    F     무료   싹틔우미    NaN    NaN    NaN 2023-03-27
# 29       50.0    F     블루     무료    NaN    NaN    NaN 2023-03-17
# ...       ...  ...    ...    ...    ...    ...    ...        ...
# 1920830   NaN  NaN    NaN    NaN    NaN    NaN    NaN 2022-11-03
# 1920840   NaN  NaN    NaN    NaN    NaN    NaN    NaN 2023-04-28
# 1920849  30.0    F     무료    NaN    NaN    NaN    NaN 2023-05-16
# 1920855  50.0    M     무료    NaN    NaN    NaN    NaN 2023-05-22
# 1920864  20.0    F     무료   싹틔우미    NaN    NaN    NaN 2022-12-24
#
#                           예매 거래시간       공연날짜  ...  최종예매가격 예매취소여부  \
# 15      0 days 00:00:00.000001645 2022-12-27  ...  120000      2
# 16      0 days 00:00:00.000002214 2023-04-12  ...  130000      0
# 20      0 days 00:00:00.000001256 2022-11-17  ...       0      0
# 28      0 days 00:00:00.000001601 2023-05-23  ...   66000      0
# 29      0 days 00:00:00.000001348 2023-05-23  ...   88000      0
# ...                           ...        ...  ...     ...    ...
# 1920830 0 days 00:00:00.000001155 2022-12-10  ...       0      0
# 1920840 0 days 00:00:00.000001242 2023-05-02  ...       0      0
# 1920849 0 days 00:00:00.000001743 2023-06-03  ...   40000      0
# 1920855 0 days 00:00:00.000001729 2023-06-13  ...   10000      0
# 1920864 0 days 00:00:00.000001223 2023-04-08  ...   21000      0
#
#                                 할인내역 공연명 코드     선예매시작일      예매시작일   장르 휴게시간  \
# 15                                일반   2631 2022-11-05 2022-10-30  교향곡  120
# 16                                일반   1684 2023-02-18 2023-02-19   합창  100
# 20                               초대권   2260        NaT 2022-11-07  교향곡   95
# 28                        싹틔우미 할인40%    221 2023-02-25 2023-02-26  클래식  150
# 29       라흐마니노프탄생150주년(8매/3.27까지)20%    221 2023-02-25 2023-02-26  클래식  150
# ...                              ...    ...        ...        ...  ...  ...
# 1920830                          초대권   2841        NaT 2022-12-03  클래식  120
# 1920840                          초대권   1218 2023-02-18 2023-02-19  교향곡  120
# 1920849                           일반   1666 2023-03-17 2023-03-18  실내악   85
# 1920855                           일반   2825 2023-05-05 2023-05-07  교향곡  120
# 1920864         청소년(만7세~만24세/본인만)30%    313        NaT 2022-12-23  교향곡  120
#
#         회원여부  member_yn
# 15        20       True
# 16        15       True
# 20        15      False
# 28        15       True
# 29        15       True
# ...      ...        ...
# 1920830    0      False
# 1920840   15      False
# 1920849   15       True
# 1920855   15       True
# 1920864    0       True
#
# [422528 rows x 22 columns]

# %%
# for x in df.columns:
#  df[(df['할인내역'] == "일반")][x].hist(bins = 120)
#  plt.title(x)
#  plt.show()

# %%
# for x in df.columns:
#     # gender F 
#     df[(df['성별'] == 'M')][x].hist(bins = 123)
#     plt.title(x)
#     plt.show()

# %%
# for x in df.columns:
#     # ticket cancel is higher than 0
#     df[(df['예매취소여부'] == 0)][x].hist(bins = 123)
#     plt.title(x)
#     plt.show()

# %%
# members = [
#      'membership_type_1',
#  'membership_type_2',
#  'membership_type_3',
#  'membership_type_4',
#  'membership_type_5',
# ]

# querynotfree = []
# for x in members:
#     querynotfree.append(df[x] != "무료")

# querynotfree = np.logical_and.reduce(querynotfree)
# for x in df.columns:
#     df[querynotfree][x].hist(bins = 123)
#     plt.title(x)
#     plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#                  나이    최종예매가격      휴게시간      회원여부  member_yn
# 나이         1.000000 -0.043316  0.001732 -0.002937        NaN
# 최종예매가격    -0.043316  1.000000 -0.014658  0.048290   0.556076
# 휴게시간       0.001732 -0.014658  1.000000  0.067763   0.003525
# 회원여부      -0.002937  0.048290  0.067763  1.000000  -0.009793
# member_yn       NaN  0.556076  0.003525 -0.009793   1.000000

# %%
# df['play_st_time'].hist(bins = 123)

# %%
# times=['0시', '1시', '2시', '3시', '4시', '5시', '6시', '7시', '8시', '9시', '10시', '11시', '12시', '13시', '14시', '15시', '16시', '17시', '18시', '19시', '20시', '21시', '22시', '23시', '24시']

# times_categorized = pd.cut(df['예매 거래시간'], bins=25, labels=times)

# for x in times:
#     df[times_categorized == x]['장르'].hist(bins = 24)
#     plt.xlabel('나이 in {}'.format(x))
#     plt.show()

# %%
실예매자 = df['예매취소여부'] == 0
좌석들 = df[실예매자]['좌석번호'].value_counts().sort_index()
# df['좌석번호'].value_counts().sort_index().plot(kind='bar')
# #split index as multiindex 
# plt.gca().set_xticklabels([])
# plt.xticks(visible=False)
# plt.show()


좌석실구매자  = df[실예매자]['좌석번호'].value_counts().sort_index()
# 좌석실구매자.plot(kind='bar')
# plt.gca().set_xticklabels([])
# plt.xticks(visible=False)
# plt.title('실구매자 좌석 구매 횟수')
# plt.show()


not실예매자 = df['예매취소여부'] != 0
not좌석실구매자  = df[not실예매자]['좌석번호'].value_counts().sort_index()
# not좌석실구매자.plot(kind='bar')
# plt.gca().set_xticklabels([])
# plt.xticks(visible=False)
# plt.title('취소자의 좌석 구매 경향')
# plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
실구매자비율 = 좌석실구매자 / (not좌석실구매자 + 좌석실구매자)
# change name of column
실구매자비율.name = "비율"

# %%
실구매자최고최소 = 실구매자비율.sort_values(ascending=True)
print(좌석들['2층 E블록8열 12'])
print(실구매자비율.describe())


save11 = pd.concat([실구매자비율, 좌석들], axis=1)
seat_price = pd.DataFrame()
# add columns to new dataframe using various methods


seat_price['평균값'] = 0
seat_price['중간값'] = 0
# seat_price['최빈값'] = 0
for x in save11.index:
    seat_price.loc[x] = [df[(df['좌석번호'] == x) & (df['예매취소여부'] == 0)]['최종예매가격'].mean(numeric_only=True),
    df[(df['좌석번호'] == x) & (df['예매취소여부'] == 0)]['최종예매가격'].median(numeric_only=True),
    # df[(df['좌석번호'] == x) & (df['예매취소여부'] == 0)]['최종예매가격'].mode()[0]
    ]
save11 = pd.concat([save11, seat_price], axis=1)
result1 = save11
# Out:
# 0
# count    2505.000000
# mean        0.765647
# std         0.088885
# min         0.492424
# 25%         0.700000
# 50%         0.773585
# 75%         0.834197
# max         0.995633
# Name: 비율, dtype: float64

# %%
plt.scatter(실구매자비율, 좌석들, 1, c=randomColor())

# plt.plot(np.linspace(0.6, 1, 100), np.linspace(210, 150, 100), c='b')
# plt.plot(np.linspace(0.75, 1, 100), np.linspace(0, 400, 100), c='b')
# plt.plot(np.linspace(0.75, 1, 100), np.linspace(700, 300, 100), c='b')
plt.show()

# %%
result1
# Out:
#                     비율  count           평균값      중간값
# 1층 A블록10열 1   0.850746    114  10929.824561      0.0
# 1층 A블록10열 10  0.851282    166  27319.277108      0.0
# 1층 A블록10열 11  0.806306    179  31363.128492      0.0
# 1층 A블록10열 2   0.863309    120  13933.333333      0.0
# 1층 A블록10열 3   0.852761    139  16280.575540      0.0
# ...                ...    ...           ...      ...
# 합창석 H블록4열 5   0.633663     64  30468.750000  22000.0
# 합창석 H블록4열 6   0.678161     59  26355.932203  24000.0
# 합창석 H블록4열 7   0.641304     59  34016.949153  27000.0
# 합창석 H블록4열 8   0.617021     58  35206.896552  22500.0
# 합창석 H블록4열 9   0.666667     56  32785.714286  26000.0
#
# [2509 rows x 4 columns]

# %%
result1[result1['평균값'] > 0].corr(numeric_only=True)

regex = r"(.+?) ([a-zA-Z])블록([0-9]+)열 ([0-9]+)"
regexalter = r"(.+?) BOX([0-9]+) ([0-9]+)"
def extract_components(index_value):
    match = re.match(regex, index_value)
    # print(match)
    if match:
        return match.groups()
    else:
        match = re.match(regexalter, index_value)
        result = list(match.groups())
        result.insert(1, 'BOX')
        return tuple(result)
    

testindex = result1.index.tolist()
components = result1.index.map(extract_components)
compwithnames = pd.MultiIndex.from_tuples(components, names=['층', '블록', '열', '좌석'])

# %%
result1.index = compwithnames

# %%
result1.reset_index(drop=False, inplace=True)
result1['열'] = result1['열'].astype(np.int32)

# %%
result1[result1['평균값'] > 0].sort_values(by='비율', ascending=False).tail(20)
# Out:
#         층   블록  열  좌석        비율  count           평균값      중간값
# 2351  합창석    G  2  24  0.559140     52  37346.153846  20500.0
# 681    1층    C  3   3  0.557756    169  61017.751479  40000.0
# 1953   3층    C  4   6  0.556522    128  31203.125000  24000.0
# 2000   3층    D  4   5  0.552846    136  32257.352941  24000.0
# 2358  합창석    G  2  30  0.548673     62  40564.516129  28500.0
# 2348  합창석    G  2  21  0.543689     56  46821.428571  47000.0
# 2429  합창석    G  4  36  0.543689     56  35500.000000  26000.0
# 1385   2층  BOX  3   1  0.538760    139  38697.841727  35000.0
# 2380  합창석    G  3  22  0.537736     57  38964.912281  28000.0
# 617    1층    C  1   2  0.537037    174  61097.701149  40000.0
# 672    1층    C  2   6  0.536388    199  60618.090452  40000.0
# 614    1층    C  1  10  0.536145    178  65842.696629  45000.0
# 1372   2층  BOX  1   2  0.535714    165  37000.000000  35000.0
# 2370  합창석    G  3  13  0.528846     55  36672.727273  30000.0
# 680    1층    C  3   2  0.516517    172  51808.139535  30000.0
# 2326  합창석    G  1  27  0.510949     70  39214.285714  29000.0
# 2251  합창석    F  2   1  0.507246     70  29985.714286  20500.0
# 624    1층    C  1   9  0.501401    179  65134.078212  45000.0
# 2262  합창석    F  2   2  0.500000     78  35166.666667  25000.0
# 2327  합창석    G  1  28  0.492424     65  36661.538462  28000.0

# %%
df[(df['좌석번호'] == '3층 D블록4열 5') & (df['예매취소여부'] == 0)]['최종예매가격'].hist(bins=10)
# Out:
# <Axes: >

# %%
total = sns.scatterplot(
    x="비율", 
    y="count", 
    data=result1[result1['평균값'] > 0], 
    legend='auto', 
    hue="층", 
    # style='열',
    s=20
)
total.set_title(
        f"전체 좌석 실예매건수",
        pad=15,
        fontsize=15,
        fontweight='bold',
        color='black',
        loc='center',
        # y=1.05,
        # x=0.5,
        ha='center',
        )
    # total.set_ylabel(
    #     total.get_ylabel(), 
    #     color='black',
    #     rotation=0,
    #     )
total.set_ylabel(
    "(건)",
    rotation = 0,
    # loc='top',
    y = 1.05,
    x = 1,
    )
total.set_xlabel("")
total.set_xticks(np.linspace(0.4, 1, 7))
total.set_xticklabels(['', '0.5', '0.6', '0.7', '0.8', '0.9', '1.0'])
total.set_yticks(np.linspace(0, 225, 10))
sns.move_legend(
    total,
    loc = "lower left",
    # bbox_to_anchor=(1.3, .5), 
    title="좌석열",
    frameon=True,
    shadow=True,
    )
plt.savefig('전체좌석실예매건수.png', dpi=600)
plt.show()

# %%
total = sns.scatterplot(
    x="비율", 
    y="평균값", 
    data=result1[result1['평균값'] > 0], 
    legend='auto', 
    hue="층", 
    # style='열',
    s=20
)
total.set_title(
        f"전체 좌석 결제금액평균",
        pad=15,
        fontsize=15,
        fontweight='bold',
        color='black',
        loc='center',
        # y=1.05,
        # x=0.5,
        ha='center',
    )
    # total.set_ylabel(
    #     total.get_ylabel(), 
    #     color='black',
    #     rotation=0,
    #     )
total.set_ylabel(
    "(원)",
    rotation = 0,
    # loc='top',
    y = 1.05,
    x = 1,
    )
total.set_xlabel("")
total.set_xticks(np.linspace(0.4, 1, 7))
total.set_xticklabels(['', '0.5', '0.6', '0.7', '0.8', '0.9', '1.0'])
total.set_yticks(
    np.linspace(0, 80000, 5, dtype=np.int64)
    )
total.set_yticklabels(
    total.get_yticks(), 
    rotation=0
    )
sns.move_legend(
    total,
    loc = "lower left",
    # bbox_to_anchor=(1.3, .5), 
    title="좌석열",
    frameon=True,
    shadow=True,
    )
plt.savefig('좌석별평균가격분포.png', dpi=600)
plt.show()

# %%
palette=['green','blue','dodgerblue','red']
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 8))
async def plot_scatter(flag = False, 층수 = '', i = 0, j = 0):
    total = sns.scatterplot(
        ax = axes[i, j],
        x="비율", 
        y="평균값", 
        data=result1[(result1['평균값'] > 0) 
                    & (result1['층'] == 층수 ) if flag == True else (result1['평균값'] > 0)
                    ], 
        legend='auto', 
        hue="열", 
        # style='열', 
        s=20,
        # palette = random.choice(palette)
        
    )
    total.set_title(
        f"{층수 if flag == True else '전체'} 좌석 거래가격 평균",
        pad=15,
        fontsize=15,
        fontweight='bold',
        color='black',
        loc='center',
        # y=1.05,
        # x=0.5,
        ha='center',
        )
    # total.set_ylabel(
    #     total.get_ylabel(), 
    #     color='black',
    #     rotation=0,
    #     )
    total.set_ylabel(
        "(원)",
        rotation = 0,
        # loc='top',
        y = 1.05,
        x = 1,
        )
    total.set_xlabel(
        '',
        
    )
    total.set_xticks(np.linspace(0.4, 1, 7))
    total.set_xticklabels(['', '0.5', '0.6', '0.7', '0.8', '0.9', '1.0'])
    total.set_yticks(
        np.linspace(0, 80000, 5, dtype=np.int64)
        )
    total.set_yticklabels(
        total.get_yticks(), 
        rotation=0
        )
    
    # sns.title("전체 좌석 비율")
    sns.move_legend(
        total,
        loc = "lower left",
        # bbox_to_anchor=(1.3, .5), 
        title="좌석열",
        frameon=True,
        shadow=True,
        )
    # plt.savefig(f"{층수 if flag == True else '전체'} 좌석 거래가격 평균"'.png', dpi=600)
    # plt.show()

층수 = result1['층'].unique().tolist()
    
for i in range(2):
    for j in range(2):
        await plot_scatter(True, 층수[0], i, j)
        층수.pop(0)
        
plt.savefig(f"총 층수별 차트.png", dpi=600)
# plot_scatter()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 8))
층수 = result1['층'].unique().tolist()
for i in range(2):
    for j in range(2):
        floorlevel = 층수[0]
        target = sns.scatterplot(
            ax=axes[i,j],
            x="비율", 
            y="count", 
            data=result1[(result1['평균값'] > 0) 
                        & (result1['층']== floorlevel)
                        ],
            legend='full', 
            hue="열", 
            # pointsize='평균값',
            s=10
            )
        target.set_title(
        "{} 실제예매건수".format(floorlevel),
        pad=15,
        fontsize=15,
        fontweight='bold',
        color='black',
        loc='center',
        # y=1.05,
        # x=0.5,
        ha='center',
        )
        target.set_xlabel("")
        target.set_ylabel("(건)", rotation = 0, loc='top')
        target.set_xticks(np.linspace(0.4, 1, 7))
        target.set_xticklabels(['', '0.5', '0.6', '0.7', '0.8', '0.9', '1.0'])
        target.set_yticks(np.linspace(0, 225, 10))
        sns.move_legend(target,
            "lower left",
            # bbox_to_anchor=(1.3, .2), 
            ncol=2, 
            title=None, 
            frameon=True,
            shadow=True,
            )
        
        층수.pop(0)
        # plt.show()
        # result1[(result1['평균값'] > 0) & (result1['층']== '1층')].corr(numeric_only=True)
plt.savefig(f"총 층수별 예매건수"".png", dpi=600)

# %%
target = sns.scatterplot(x="비율", y="count", data=result1[(result1['평균값'] > 0) & (result1['층']== floorlevel)], legend='full', hue="블록", s=10)
target.set_title("{} 실제예매건수".format(floorlevel))
sns.move_legend(target,"lower center",
    bbox_to_anchor=(1.3, .2), ncol=3, title=None, frameon=False)
plt.show()

# %%
floorlevel = "1층"

target = sns.scatterplot(
    x="비율", 
    y="count", 
    data=
    result1[(result1['평균값'] > 0) 
            &(result1['층']== floorlevel) 
            # &(result1['열'] == i)
            ], 
    legend='full', 
    hue="블록", 
    style="열",
    s=50, 
    palette=sns.color_palette("hls", 8)
    )
target.set_title("{} 실제예매건수".format(floorlevel))
sns.move_legend(target,"lower center",
    bbox_to_anchor=(1.3, .2), ncol=3, title=None, frameon=False)
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_3008\2925462543.py:3: UserWarning: The palette list has more values (8) than needed (5), which may not be intended.
#   target = sns.scatterplot(

# %%
# 조회 결과 장애인석
result1[(result1['층'] == "1층") & (result1['count'] < 50)]
# Out:
#       층 블록   열 좌석        비율  count           평균값      중간값
# 656  1층  C  22  1  0.871795     34  25823.529412   7500.0
# 657  1층  C  22  2  0.870968     27  24111.111111   5000.0
# 658  1층  C  22  3  0.777778     14  48571.428571  17500.0
# 659  1층  C  22  4  0.857143     12  52166.666667  15500.0
# 660  1층  C  22  5  0.909091     10  16300.000000   9500.0
# 661  1층  C  22  6  0.900000      9  13555.555556   3000.0
# 662  1층  C  22  7  0.857143     12  61333.333333  28000.0
# 663  1층  C  22  8  0.750000     12  63333.333333  22000.0

# %%
# 조회 결과 장애인석 2층
result1[(result1['층'] == "2층") & (result1['count'] < 50)]
# Out:
#        층 블록  열  좌석        비율  count           평균값      중간값
# 1361  2층  A  8   1  0.884615     23  20782.608696  18000.0
# 1362  2층  A  8  12       NaN      0           NaN      NaN
# 1363  2층  A  8  13       NaN      0           NaN      NaN
# 1364  2층  A  8   2  0.950000     19  17684.210526  10000.0
# 1365  2층  A  8   3  0.950000     19  21263.157895  16000.0
# 1366  2층  A  8   4  0.941176     16  29250.000000  14000.0
# 1367  2층  A  8   5  0.937500     15  29600.000000  15000.0
# 1368  2층  A  8   6  0.894737     17  15470.588235  15000.0
# 1369  2층  A  8   7  0.880952     37  30918.918919  18000.0
# 1370  2층  A  8   8  0.846154     44  33659.090909  20000.0
# 1796  2층  E  8   1  0.964286     27  20333.333333  15000.0
# 1797  2층  E  8  12       NaN      0           NaN      NaN
# 1798  2층  E  8  13       NaN      0           NaN      NaN
# 1799  2층  E  8   2  0.958333     23  17913.043478  12000.0
# 1800  2층  E  8   3  0.840000     21  18476.190476  12000.0
# 1801  2층  E  8   4  0.875000     21  27523.809524  15000.0
# 1802  2층  E  8   5  0.937500     30  28400.000000  20000.0
# 1803  2층  E  8   6  0.935484     29  33000.000000  16000.0
# 1804  2층  E  8   7  0.971429     34  25500.000000  17000.0
# 1805  2층  E  8   8  0.880952     37  27783.783784  18000.0

# %%
result1[result1['평균값'] > 0].corr(numeric_only=True)

regex = r"(.+?) ([a-zA-Z0-9])블록([0-9]+)열 ([0-9]+)"
regexalter = r"(.+?) BOX([0-9]+) ([0-9]+)"
def extract_components(index_value):
    match = re.match(regex, index_value)
    # print(match)
    if match:
        return match.groups()
    else:
        match = re.match(regexalter, index_value)
        result = list(match.groups())
        result.insert(1, 'BOX')
        return tuple(result)
    

df_copied = df_test[df_test['place'] == "콘서트홀"].copy()
df_copied['seat'] = df_copied['seat'].apply(lambda x : extract_components(x))
df_copied[['층','블록','열','상세좌석']] = pd.DataFrame(df_copied['seat'].tolist(), columns=['층','블록','열','상세좌석'])
